# %%
# import packages
import torch
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
from qiskit_machine_learning.utils import algorithm_globals
from torch import nn
import pandas as pd
from scipy.stats import rankdata
import torch.nn.functional as F

# %%
#load dataset

sp500 = yf.download('^GSPC', start='2010-01-01', end='2018-12-31')
dowjones = yf.download('^DJI', start='2010-01-01', end='2018-12-31')

# Compared to the Apple and Microsoft plot they have in the paper, this gives a similar result. To get it using amplitude encoding,
# we do need to preprocess the data as we were doing before, so putting it in a probability distribution.
sp500_returns = sp500['Close'].pct_change().dropna()
sp_returns = sp500['Close'].dropna().values

dowjones_returns = dowjones['Close'].pct_change().dropna()
dj_returns = dowjones['Close'].dropna().values


# encode in state amplitude
# We have 8192 datapoints, so we need 13 qubits to encode them
num_qubits = 3
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
def empirical_cdf(data):
    ranks = rankdata(data, method='average')  # Rank the data
    uniform_data = ranks / (len(data) + 1)    # Normalize to [0, 1]
    return uniform_data

sp500_uniform = empirical_cdf(sp500_returns)
dj_uniform = empirical_cdf(dowjones_returns)

# Plot the scatter plot of returns
plt.figure(figsize=(8, 6))
plt.scatter(sp500_returns, dowjones_returns, alpha=0.6, c='blue', edgecolor='k')
plt.title("Scatter plot of S&P500 and DJI returns")
plt.xlabel("AAPL Uniform Returns")
plt.ylabel("MSFT Uniform Returns")
plt.grid(alpha=0.3)
plt.show()


# Plot the scatter plot of uniform returns
plt.figure(figsize=(8, 6))
plt.scatter(sp500_uniform, dj_uniform, alpha=0.6, c='blue', edgecolor='k')
plt.title("Scatter plot of S&P500 and DJI returns")
plt.xlabel("AAPL Uniform Returns")
plt.ylabel("MSFT Uniform Returns")
plt.grid(alpha=0.3)
plt.show()

# %%
data_stack = np.column_stack((sp500_uniform,dj_uniform))
df2 = pd.DataFrame({
    'SP500': sp500_uniform,
    'DJI': dj_uniform
})

# %%
from copulas.bivariate import Clayton

copulas = Clayton()
copulas.fit(data_stack)

samples = copulas.sample(len(data_stack))
samples = pd.DataFrame(samples, columns=['SP500', 'DJI'])
print(samples)
# Out:
#          SP500       DJI
# 0     0.250413  0.235678
# 1     0.554422  0.603328
# 2     0.340693  0.354226
# 3     0.322506  0.382135
# 4     0.767567  0.474330
# ...        ...       ...
# 2257  0.958900  0.989113
# 2258  0.392788  0.293188
# 2259  0.568318  0.870261
# 2260  0.896825  0.958216
# 2261  0.775519  0.922008
#
# [2262 rows x 2 columns]

# %%
from copulas.visualization import compare_2d
compare_2d(df2, samples)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\edgar\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File c:\Users\edgar\AppData\Local\Programs\Python\Python312\Lib\site-packages\plotly\io\_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
#     390             "Mime type rendering requires ipython but it is not installed"
#     391         )
#     393     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 394         raise ValueError(
#     395             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     396         )
#     398     ipython_display.display(bundle, raw=True)
#     400 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'Data=Real<br>SP500=%{x}<br>DJI=%{y}<extra></extra>',
#               'legendgroup': 'Real',
#               'marker': {'color': '#000036', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Real',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([0.66018559, 0.50198851, 0.70172338, ..., 0.99955811, 0.85947857,
#                           0.36765356]),
#               'xaxis': 'x',
#               'y': array([0.37693327, 0.46752099, 0.66239505, ..., 0.99955811, 0.91559876,
#                           0.25055236]),
#               'yaxis': 'y'},
#              {'hovertemplate': 'Data=Synthetic<br>SP500=%{x}<br>DJI=%{y}<extra></extra>',
#               'legendgroup': 'Synthetic',
#               'marker': {'color': '#01E0C9', 'symbol': 'diamond'},
#               'mode': 'markers',
#               'name': 'Synthetic',
#               'showlegend': True,
#               'type': 'scattergl',
#               'x': array([0.25041296, 0.55442225, 0.34069309, ..., 0.56831838, 0.89682467,
#                           0.77551881]),
#               'xaxis': 'x',
#               'y': array([0.23567798, 0.60332837, 0.35422621, ..., 0.8702606 , 0.95821628,
#                           0.92200767]),
#               'yaxis': 'y'}],
#     'layout': {'font': {'size': 18},
#                'legend': {'title': {'text': 'Data'}, 'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'plot_bgcolor': '#F5F5F8',
#                'showlegend': True,
#                'template': '...',
#                'title': {'text': "Real vs. Synthetic Data for columns 'SP500' and 'DJI'"},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'SP500'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'DJI'}}}
# })

# %%
from qiskit import QuantumCircuit, QuantumRegister, transpile
from qiskit.circuit.library import RXXGate
def create_bell_pair_circuit(num_qubits=num_qubits):
    # Create two quantum registers A and B with num_qubits each
    qr_a = QuantumRegister(num_qubits, 'A')
    qr_b = QuantumRegister(num_qubits, 'B')
    qc = QuantumCircuit(qr_a, qr_b)

    # Step 1: Apply H gates to all qubits in register A
    qc.h(qr_a)

    # Step 2: Apply CNOT gates between corresponding qubits in A and B
    for i in range(num_qubits):
        qc.cx(qr_a[i], qr_b[i])

    return qc

# %%
# define generator
from qiskit_aer import AerSimulator

shots = 2048
class QCBM:
    def __init__(self, num_qubits, layers=1):
        self.num_qubits = num_qubits
        self.layers = layers
        self.params = np.random.uniform(0, 2 * np.pi, size=(layers, 2 * num_qubits))
        self.backend = AerSimulator()

    def set_params(self, params):
        # Update the generator's parameters
        self.params = params
        
    def build_circuit(self, params):
        from qiskit import QuantumCircuit, QuantumRegister
        from qiskit.circuit.library import RZGate, RXGate, CXGate

        # Ensure params are a NumPy array
        params = np.array(params)  # Ensure parameters are in NumPy format

        # Build a two-register circuit so the measurement yields 2*num_qubits bits:
        def add_unitary_layers(qc, qr, num_layers):
            num_qubits = len(qr)
            for layer in range(num_layers):
                for i in range(num_qubits):
                    qc.rz(float(params[layer, 2 * i]), qr[i])
                    qc.rx(float(params[layer, 2 * i + 1]), qr[i])
                for i in range(num_qubits - 1):
                    qc.append(RXXGate(float(params[layer, 2 * i])), [qr[i], qr[i+1]])
            return qc

        qr_a = QuantumRegister(self.num_qubits, 'A')
        qr_b = QuantumRegister(self.num_qubits, 'B')
        qc = create_bell_pair_circuit(self.num_qubits)
        qc = add_unitary_layers(qc, qr_a, self.layers)
        qc = add_unitary_layers(qc, qr_b, self.layers)
        qc.measure_all()
        return qc


    def run(self, params):
        circuit = self.build_circuit(params)
        circuit = transpile(circuit, backend=self.backend)
        job = self.backend.run(circuit, shots=shots)
        result = job.result()
        counts = result.get_counts()
        return counts

# %%
# define loss functions
def kl_divergence(p, q):
    epsilon = 1e-6  # Prevent division by zero
    p = np.clip(p, epsilon, 1.0)
    q = np.clip(q, epsilon, 1.0)
    return np.sum(p * np.log(p / q))

# %%
def spsa_gradient_estimator(C, theta_k, c, delta_k):
    """Estimate the gradient using SPSA."""
    perturbed_theta_plus = theta_k + c * delta_k
    perturbed_theta_minus = theta_k - c * delta_k

    # Compute the cost function for perturbed parameters
    C_plus = C(perturbed_theta_plus)
    C_minus = C(perturbed_theta_minus)

    # Debug: Print cost function values
    print(f"C_plus: {C_plus}, C_minus: {C_minus}")

    # Gradient estimator formula
    gradient_estimate = (C_plus - C_minus) / (2 * c * delta_k)

    # Debug: Check gradient estimate
    print("Gradient estimate:", gradient_estimate)
    return gradient_estimate

def spsa_update(theta_k, C, a, c, gamma, k):
    """Perform one step of SPSA update."""
    # Generate random perturbation vector delta_k
    delta_k = np.random.choice([-1, 1], size=len(theta_k))

    # Debug: Print shapes
    print("theta_k shape:", theta_k.shape)
    print("delta_k shape:", delta_k.shape)

    # Estimate the gradient using SPSA
    gradient_estimate = spsa_gradient_estimator(C, theta_k, c, delta_k)

    # Debug: Check gradient values
    print("Gradient estimate shape:", gradient_estimate.shape)

    # Update the parameter based on the SPSA update rule
    theta_k_plus_1 = theta_k - (a / k) * gradient_estimate

    # Debug: Check updated parameters
    print("Updated theta_k_plus_1:", theta_k_plus_1)
    return theta_k_plus_1
print("Samples shape:", samples.shape)
# Out:
# Samples shape: (2262, 2)

# %%
num_qubits_per_register = 3
layers = 1
qcbm = QCBM(num_qubits_per_register, layers)
a = 0.008
c = 0.01
gamma = 0.101

print("Min value in data_stack:", np.min(data_stack))
print("Max value in data_stack:", np.max(data_stack))
# Target distribution (normalized histogram of real data)
target_distribution = data_stack/29500

# Training Loop
num_iterations = 1000
cost_history = []

for iteration in range(num_iterations):
    # Generate data
    if len(target_distribution.shape) == 1:
        target_distribution = target_distribution.reshape(-1, 2)
    counts = qcbm.run(qcbm.params)
    generated_distribution = np.zeros_like(target_distribution)
    for bitstring, count in counts.items():
        idx = int(bitstring, 2)
        generated_distribution[idx] += count
    generated_distribution /= np.sum(generated_distribution)

    # Compute KL divergence
    cost = kl_divergence(target_distribution, generated_distribution)
    cost_history.append(cost)

    # Update parameters with SPSA
    def loss_fn(params):
        counts = qcbm.run(params)
        generated_distribution = np.zeros_like(target_distribution)
        for bitstring, count in counts.items():
            idx = int(bitstring, 2)
            generated_distribution[idx] += count
        generated_distribution /= np.sum(generated_distribution)
        return kl_divergence(target_distribution, generated_distribution)

    qcbm.params = spsa_update( qcbm.params,loss_fn,a, c, gamma, iteration + 1)

    if iteration % 10 == 0:
        print(f"Iteration {iteration}/{num_iterations}, KL Divergence: {cost:.6f}")

hist, edges = np.histogramdd(data_stack, bins=16, density=True)
t_distribution = hist.flatten() / np.sum(hist)
print("Target distribution sum:", np.sum(t_distribution))
# Plot the cost function
plt.plot(range(num_iterations), cost_history)
plt.xlabel("Iteration")
plt.ylabel("KL Divergence")
plt.title("QCBM Training Progress")
plt.show()
# Out:
# Min value in data_stack: 0.0004418912947414936
# Max value in data_stack: 0.9995581087052585
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21784570372231668, C_minus: 0.21770113788543455
# Gradient estimate: [0.00722829]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02192661 0.16157052 4.51174588 0.38093203 0.3384746  3.75099175]]
# Iteration 0/1000, KL Divergence: 0.217345
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21801138052241703, C_minus: 0.21707938807303098
# Gradient estimate: [-0.04659962]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02211301 0.16175691 4.51193228 0.38111843 0.338661   3.75117814]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21782509230029456, C_minus: 0.21751814223413882
# Gradient estimate: [-0.0153475]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02215393 0.16179784 4.5119732  0.38115936 0.33870193 3.75121907]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2175357635236772, C_minus: 0.21764366779427113
# Gradient estimate: [-0.00539521]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02216472 0.16180863 4.511984   0.38117015 0.33871272 3.75122986]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21794908254364598, C_minus: 0.21696422360231604
# Gradient estimate: [0.04924295]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02208593 0.16172984 4.51190521 0.38109136 0.33863393 3.75115107]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21693650457001556, C_minus: 0.2172489871778384
# Gradient estimate: [-0.01562413]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02210677 0.16175068 4.51192604 0.38111219 0.33865476 3.7511719 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21706803361502647, C_minus: 0.21802377992915828
# Gradient estimate: [-0.04778732]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02216138 0.16180529 4.51198065 0.3811668  0.33870937 3.75122652]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2183070779836307, C_minus: 0.2171270318835507
# Gradient estimate: [-0.05900231]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02222038 0.16186429 4.51203966 0.38122581 0.33876838 3.75128552]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2184390889614181, C_minus: 0.21756971398833255
# Gradient estimate: [-0.04346875]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02225902 0.16190293 4.51207829 0.38126444 0.33880701 3.75132416]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21691231940321476, C_minus: 0.21762778806418467
# Gradient estimate: [-0.03577343]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02228764 0.16193155 4.51210691 0.38129306 0.33883563 3.75135278]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21824215099829922, C_minus: 0.21778276699033525
# Gradient estimate: [-0.0229692]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02230435 0.16194825 4.51212362 0.38130977 0.33885234 3.75136948]]
# Iteration 10/1000, KL Divergence: 0.218385
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21786416009686516, C_minus: 0.2162695451317103
# Gradient estimate: [-0.07973075]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0223575  0.16200141 4.51217677 0.38136292 0.33890549 3.75142264]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2178800269227367, C_minus: 0.21804165934312256
# Gradient estimate: [-0.00808162]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02236247 0.16200638 4.51218174 0.3813679  0.33891046 3.75142761]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21803291918973028, C_minus: 0.21784598293572338
# Gradient estimate: [-0.00934681]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02236781 0.16201172 4.51218709 0.38137324 0.33891581 3.75143295]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21722349839288102, C_minus: 0.21815684027540275
# Gradient estimate: [-0.04666709]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0223927  0.16203661 4.51221197 0.38139813 0.3389407  3.75145784]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21804069880001384, C_minus: 0.21803556094610158
# Gradient estimate: [-0.00025689]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02239283 0.16203674 4.5122121  0.38139825 0.33894082 3.75145797]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21723214217921208, C_minus: 0.21744021356352328
# Gradient estimate: [-0.01040357]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02239773 0.16204164 4.512217   0.38140315 0.33894572 3.75146287]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21761288404829554, C_minus: 0.21767745224755197
# Gradient estimate: [0.00322841]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02239629 0.1620402  4.51221556 0.38140172 0.33894428 3.75146143]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21784992529780428, C_minus: 0.21782192772509446
# Gradient estimate: [0.00139988]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0223957  0.16203961 4.51221497 0.38140113 0.3389437  3.75146084]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21773177597408677, C_minus: 0.21714268611951673
# Gradient estimate: [0.02945449]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02238392 0.16202783 4.51220319 0.38138934 0.33893191 3.75144906]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21719975466165234, C_minus: 0.2175046206672296
# Gradient estimate: [-0.0152433]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02238973 0.16203364 4.512209   0.38139515 0.33893772 3.75145487]]
# Iteration 20/1000, KL Divergence: 0.216973
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21848360169330874, C_minus: 0.21776116630541717
# Gradient estimate: [-0.03612177]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02240286 0.16204677 4.51222214 0.38140829 0.33895086 3.751468  ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2178543490719983, C_minus: 0.21774683886680712
# Gradient estimate: [-0.00537551]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02240473 0.16204864 4.512224   0.38141016 0.33895273 3.75146987]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2172795435606516, C_minus: 0.21704957764612734
# Gradient estimate: [-0.0114983]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02240857 0.16205247 4.51222784 0.38141399 0.33895656 3.7514737 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21725308709858315, C_minus: 0.21724580526146808
# Gradient estimate: [-0.00036409]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02240868 0.16205259 4.51222795 0.38141411 0.33895667 3.75147382]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21726109357950876, C_minus: 0.21732003933778132
# Gradient estimate: [-0.00294729]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02240959 0.1620535  4.51222886 0.38141501 0.33895758 3.75147473]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21764884172965343, C_minus: 0.21819458776743395
# Gradient estimate: [-0.0272873]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02241767 0.16206158 4.51223695 0.3814231  0.33896567 3.75148281]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21689476955666492, C_minus: 0.21847848528937489
# Gradient estimate: [0.07918579]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02239505 0.16203896 4.51221432 0.38140047 0.33894304 3.75146019]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21792420162847265, C_minus: 0.21717678072606697
# Gradient estimate: [-0.03737105]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02240536 0.16204927 4.51222463 0.38141078 0.33895335 3.7514705 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21774517780032857, C_minus: 0.21747992673132832
# Gradient estimate: [0.01326255]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02240182 0.16204573 4.51222109 0.38140725 0.33894981 3.75146696]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2177491340757735, C_minus: 0.21696055536167608
# Gradient estimate: [-0.03942894]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.022412   0.16205591 4.51223127 0.38141742 0.33895999 3.75147714]]
# Iteration 30/1000, KL Divergence: 0.217596
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21769481962170678, C_minus: 0.21719691994165646
# Gradient estimate: [-0.02489498]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02241822 0.16206213 4.51223749 0.38142364 0.33896621 3.75148336]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21749062107520042, C_minus: 0.21774018654957483
# Gradient estimate: [0.01247827]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0224152  0.1620591  4.51223447 0.38142062 0.33896319 3.75148033]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21698275109492793, C_minus: 0.21917290824474428
# Gradient estimate: [-0.10950786]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02244096 0.16208487 4.51226023 0.38144639 0.33898895 3.7515061 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21798278425263595, C_minus: 0.21732932193165738
# Gradient estimate: [0.03267312]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02243349 0.1620774  4.51225277 0.38143892 0.33898149 3.75149863]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2181230467218952, C_minus: 0.21792086448543369
# Gradient estimate: [0.01010911]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02243125 0.16207516 4.51225052 0.38143667 0.33897924 3.75149639]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21681237002165815, C_minus: 0.21794342888058443
# Gradient estimate: [-0.05655294]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02244348 0.16208738 4.51226275 0.3814489  0.33899147 3.75150861]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21766077815879162, C_minus: 0.21800217783716375
# Gradient estimate: [0.01706998]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02243988 0.16208379 4.51225915 0.3814453  0.33898787 3.75150502]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21733476697827459, C_minus: 0.2177524206366117
# Gradient estimate: [-0.02088268]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02244417 0.16208807 4.51226344 0.38144959 0.33899216 3.7515093 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2172290967071615, C_minus: 0.2172255770666077
# Gradient estimate: [0.00017598]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02244413 0.16208804 4.5122634  0.38144955 0.33899212 3.75150927]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21810077137291803, C_minus: 0.21773960659538255
# Gradient estimate: [0.01805824]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02244061 0.16208452 4.51225988 0.38144603 0.3389886  3.75150575]]
# Iteration 40/1000, KL Divergence: 0.216958
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.217948488102947, C_minus: 0.21793525131014757
# Gradient estimate: [0.00066184]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02244048 0.16208439 4.51225975 0.3814459  0.33898847 3.75150562]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21743306516871508, C_minus: 0.21701396434967196
# Gradient estimate: [-0.02095504]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02244438 0.16208829 4.51226365 0.3814498  0.33899237 3.75150952]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21767717724957986, C_minus: 0.21818370685737093
# Gradient estimate: [-0.02532648]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02244898 0.16209289 4.51226826 0.38145441 0.33899698 3.75151412]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21869685536592737, C_minus: 0.21839454161823582
# Gradient estimate: [-0.01511569]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02245167 0.16209558 4.51227094 0.38145709 0.33899966 3.75151681]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2167957012320971, C_minus: 0.21742926855757497
# Gradient estimate: [0.03167837]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02244616 0.16209007 4.51226543 0.38145159 0.33899415 3.7515113 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2173773932084168, C_minus: 0.21854169816622068
# Gradient estimate: [-0.05821525]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02245607 0.16209998 4.51227534 0.38146149 0.33900406 3.75152121]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21752735836706766, C_minus: 0.2176646848887476
# Gradient estimate: [-0.00686633]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02245722 0.16210112 4.51227649 0.38146264 0.33900521 3.75152235]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21818261882366807, C_minus: 0.2171426761874934
# Gradient estimate: [-0.05199713]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0224657  0.16210961 4.51228498 0.38147113 0.3390137  3.75153084]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21718079258566697, C_minus: 0.21764854435396186
# Gradient estimate: [0.02338759]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02246196 0.16210587 4.51228123 0.38146739 0.33900996 3.7515271 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21717063568001538, C_minus: 0.21714168307554543
# Gradient estimate: [-0.00144763]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02246219 0.1621061  4.51228146 0.38146761 0.33901018 3.75152733]]
# Iteration 50/1000, KL Divergence: 0.217993
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21758272181650926, C_minus: 0.21638366813042234
# Gradient estimate: [-0.05995268]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02247141 0.16211532 4.51229069 0.38147684 0.33901941 3.75153655]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21741217702052226, C_minus: 0.21768209876893752
# Gradient estimate: [0.01349609]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02246938 0.16211328 4.51228865 0.3814748  0.33901737 3.75153451]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2184767396707584, C_minus: 0.21727465763090792
# Gradient estimate: [-0.0601041]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02247828 0.16212219 4.51229755 0.3814837  0.33902627 3.75154342]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2171450165118501, C_minus: 0.2186239455272261
# Gradient estimate: [-0.07394645]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02248904 0.16213295 4.51230831 0.38149446 0.33903703 3.75155417]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21692899735361765, C_minus: 0.2185910939665265
# Gradient estimate: [-0.08310483]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02250091 0.16214482 4.51232018 0.38150633 0.3390489  3.75156605]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21694601539287925, C_minus: 0.21847427126502092
# Gradient estimate: [-0.07641279]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02251163 0.16215554 4.51233091 0.38151706 0.33905963 3.75157677]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21746730659364752, C_minus: 0.21794088023388866
# Gradient estimate: [-0.02367868]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0225149  0.16215881 4.51233417 0.38152032 0.33906289 3.75158004]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21705183494218633, C_minus: 0.21787071292252236
# Gradient estimate: [-0.0409439]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02252045 0.16216436 4.51233972 0.38152587 0.33906844 3.75158559]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21671636041340878, C_minus: 0.2173142017989219
# Gradient estimate: [0.02989207]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02251647 0.16216037 4.51233574 0.38152189 0.33906446 3.7515816 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2172164720181812, C_minus: 0.21858168789857393
# Gradient estimate: [-0.06826079]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02252542 0.16216933 4.51234469 0.38153084 0.33907341 3.75159056]]
# Iteration 60/1000, KL Divergence: 0.217973
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21810124550121543, C_minus: 0.21772845351221437
# Gradient estimate: [0.0186396]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02252301 0.16216692 4.51234228 0.38152844 0.339071   3.75158815]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21690755561721578, C_minus: 0.21813396079220823
# Gradient estimate: [-0.06132026]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0225308  0.16217471 4.51235007 0.38153622 0.33907879 3.75159594]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21746879222197457, C_minus: 0.21839966027728047
# Gradient estimate: [0.0465434]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02252498 0.16216889 4.51234425 0.3815304  0.33907297 3.75159012]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21780019603213707, C_minus: 0.21651742485765407
# Gradient estimate: [-0.06413856]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02253288 0.16217678 4.51235215 0.3815383  0.33908087 3.75159801]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2182013390951913, C_minus: 0.21727490478057981
# Gradient estimate: [-0.04632172]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02253849 0.1621824  4.51235776 0.38154391 0.33908648 3.75160363]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2174212064728739, C_minus: 0.21755242747102801
# Gradient estimate: [0.00656105]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02253771 0.16218162 4.51235698 0.38154313 0.3390857  3.75160284]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21768471628807615, C_minus: 0.21695992401744457
# Gradient estimate: [-0.03623961]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02254197 0.16218588 4.51236124 0.38154739 0.33908996 3.75160711]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2176082718093143, C_minus: 0.2176048471020669
# Gradient estimate: [0.00017124]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02254195 0.16218586 4.51236122 0.38154737 0.33908994 3.75160709]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21752389115105064, C_minus: 0.2173548673947245
# Gradient estimate: [-0.00845119]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02254292 0.16218682 4.51236219 0.38154834 0.33909091 3.75160805]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21762318948387308, C_minus: 0.21750984135762702
# Gradient estimate: [-0.00566741]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02254355 0.16218746 4.51236283 0.38154898 0.33909155 3.75160869]]
# Iteration 70/1000, KL Divergence: 0.216769
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21718225872985816, C_minus: 0.21731905843801483
# Gradient estimate: [-0.00683999]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02254431 0.16218822 4.51236359 0.38154974 0.33909231 3.75160945]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21770073246412125, C_minus: 0.2167850597623713
# Gradient estimate: [-0.04578364]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02254933 0.16219324 4.5123686  0.38155475 0.33909732 3.75161447]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21775345102744198, C_minus: 0.21781419043311634
# Gradient estimate: [0.00303697]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.022549   0.16219291 4.51236828 0.38155443 0.339097   3.75161414]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2166794621873089, C_minus: 0.217716248091157
# Gradient estimate: [-0.0518393]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02255453 0.16219844 4.51237381 0.38155996 0.33910253 3.75161967]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21807734840279214, C_minus: 0.21782348094231374
# Gradient estimate: [0.01269337]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0225532  0.16219711 4.51237247 0.38155862 0.33910119 3.75161834]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2177525830101099, C_minus: 0.21724085934006038
# Gradient estimate: [0.02558618]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02255054 0.16219445 4.51236981 0.38155596 0.33909853 3.75161568]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2172715396904437, C_minus: 0.21735943458795187
# Gradient estimate: [0.00439474]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02255009 0.162194   4.51236936 0.38155551 0.33909808 3.75161523]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2176435935100416, C_minus: 0.2170813889572844
# Gradient estimate: [-0.02811023]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02255293 0.16219684 4.51237221 0.38155836 0.33910093 3.75161807]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21732278195705923, C_minus: 0.2171117724431455
# Gradient estimate: [0.01055048]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02255188 0.16219579 4.51237115 0.3815573  0.33909987 3.75161702]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2174843632946724, C_minus: 0.21719765637252952
# Gradient estimate: [-0.01433535]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0225533  0.1621972  4.51237257 0.38155872 0.33910129 3.75161843]]
# Iteration 80/1000, KL Divergence: 0.217766
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21778121127055794, C_minus: 0.21772635510275792
# Gradient estimate: [0.00274281]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02255303 0.16219694 4.5123723  0.38155845 0.33910102 3.75161817]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2182757022325299, C_minus: 0.21767672451260314
# Gradient estimate: [-0.02994889]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02255591 0.16219982 4.51237519 0.38156134 0.33910391 3.75162105]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21760468846464295, C_minus: 0.21684493209707348
# Gradient estimate: [-0.03798782]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02255953 0.16220344 4.5123788  0.38156496 0.33910752 3.75162467]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21745243309531936, C_minus: 0.21712696681365515
# Gradient estimate: [-0.01627331]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256106 0.16220497 4.51238034 0.38156649 0.33910906 3.7516262 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21761032736326574, C_minus: 0.21764257789605124
# Gradient estimate: [-0.00161253]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256121 0.16220512 4.51238049 0.38156664 0.33910921 3.75162635]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21721844003531732, C_minus: 0.21741832872956818
# Gradient estimate: [0.00999443]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256029 0.1622042  4.51237957 0.38156572 0.33910829 3.75162543]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21788312792705006, C_minus: 0.21760897599249074
# Gradient estimate: [0.0137076]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02255905 0.16220296 4.51237832 0.38156447 0.33910704 3.75162419]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2174246166815777, C_minus: 0.21755340356730252
# Gradient estimate: [0.00643934]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02255847 0.16220238 4.51237774 0.38156389 0.33910646 3.75162361]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21727126747332687, C_minus: 0.21767193644950295
# Gradient estimate: [0.02003345]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02255669 0.1622006  4.51237596 0.38156211 0.33910468 3.75162183]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21695146983976515, C_minus: 0.21806448046979032
# Gradient estimate: [-0.05565053]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256158 0.16220549 4.51238085 0.381567   0.33910957 3.75162672]]
# Iteration 90/1000, KL Divergence: 0.218345
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2172822757879975, C_minus: 0.21652094432225533
# Gradient estimate: [-0.03806657]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256489 0.1622088  4.51238416 0.38157031 0.33911288 3.75163003]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21730812467720298, C_minus: 0.21690593161070373
# Gradient estimate: [-0.02010965]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256662 0.16221053 4.51238589 0.38157204 0.33911461 3.75163176]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21677579480870826, C_minus: 0.21655883800586764
# Gradient estimate: [-0.01084784]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256754 0.16221145 4.51238682 0.38157297 0.33911554 3.75163268]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21734999915450484, C_minus: 0.21774880037015992
# Gradient estimate: [-0.01994006]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256922 0.16221313 4.5123885  0.38157465 0.33911722 3.75163436]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21684614451892853, C_minus: 0.2174523790199926
# Gradient estimate: [0.03031173]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0225667  0.16221061 4.51238597 0.38157212 0.33911469 3.75163184]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21738376979382265, C_minus: 0.21733873719650929
# Gradient estimate: [-0.00225163]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256688 0.16221079 4.51238616 0.38157231 0.33911488 3.75163202]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21735453907635213, C_minus: 0.2176503557125817
# Gradient estimate: [0.01479083]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256568 0.16220958 4.51238495 0.3815711  0.33911367 3.75163081]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21747158013987353, C_minus: 0.2175941772336495
# Gradient estimate: [-0.00612985]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256617 0.16221008 4.51238544 0.38157159 0.33911416 3.75163131]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21641244454502778, C_minus: 0.2180340796429002
# Gradient estimate: [-0.08108175]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02257266 0.16221657 4.51239193 0.38157808 0.33912065 3.7516378 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21710165579927165, C_minus: 0.21821683886325072
# Gradient estimate: [0.05575915]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256824 0.16221215 4.51238751 0.38157366 0.33911623 3.75163338]]
# Iteration 100/1000, KL Divergence: 0.217115
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21740669085844297, C_minus: 0.21770317386343216
# Gradient estimate: [0.01482415]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256708 0.16221099 4.51238635 0.3815725  0.33911507 3.75163222]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21789861008020145, C_minus: 0.2173303113474586
# Gradient estimate: [0.02841494]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256487 0.16220878 4.51238414 0.38157029 0.33911286 3.75163001]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21747370532791596, C_minus: 0.21750858635432901
# Gradient estimate: [0.00174405]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256474 0.16220865 4.51238401 0.38157016 0.33911273 3.75162988]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2174458441587632, C_minus: 0.21706359280218315
# Gradient estimate: [0.01911257]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256328 0.16220719 4.51238255 0.3815687  0.33911127 3.75162842]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21742434653788864, C_minus: 0.21749492432652148
# Gradient estimate: [-0.00352889]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256355 0.16220746 4.51238282 0.38156897 0.33911154 3.75162869]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21821658595986312, C_minus: 0.2177197851022658
# Gradient estimate: [-0.02484004]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256541 0.16220931 4.51238468 0.38157083 0.3391134  3.75163054]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21708524997069556, C_minus: 0.2178412648578583
# Gradient estimate: [-0.03780074]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02256821 0.16221211 4.51238748 0.38157363 0.3391162  3.75163334]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21817014808160196, C_minus: 0.21747993871269602
# Gradient estimate: [-0.03451047]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02257074 0.16221465 4.51239001 0.38157616 0.33911873 3.75163588]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21850606712657197, C_minus: 0.21793528811719434
# Gradient estimate: [-0.02853895]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02257281 0.16221672 4.51239209 0.38157824 0.33912081 3.75163795]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21748854812859797, C_minus: 0.2168029145160417
# Gradient estimate: [-0.03428168]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02257528 0.16221919 4.51239456 0.38158071 0.33912328 3.75164042]]
# Iteration 110/1000, KL Divergence: 0.217721
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21723859509520077, C_minus: 0.21780239723505823
# Gradient estimate: [-0.02819011]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0225773  0.16222121 4.51239657 0.38158272 0.33912529 3.75164244]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.217219780015697, C_minus: 0.21757370357661185
# Gradient estimate: [0.01769618]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02257605 0.16221995 4.51239532 0.38158147 0.33912404 3.75164118]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21739333184607543, C_minus: 0.21830420875895648
# Gradient estimate: [0.04554385]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02257285 0.16221676 4.51239212 0.38157827 0.33912084 3.75163799]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21807557588512264, C_minus: 0.21683672435573956
# Gradient estimate: [-0.06194258]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02257716 0.16222107 4.51239643 0.38158258 0.33912515 3.7516423 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21649668143806344, C_minus: 0.21785046352680285
# Gradient estimate: [0.0676891]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02257249 0.1622164  4.51239176 0.38157791 0.33912048 3.75163763]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2169139440725205, C_minus: 0.21805073970508695
# Gradient estimate: [-0.05683978]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02257638 0.16222028 4.51239565 0.3815818  0.33912437 3.75164151]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21789227881477127, C_minus: 0.21731713031030964
# Gradient estimate: [0.02875743]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02257443 0.16221834 4.5123937  0.38157985 0.33912242 3.75163956]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2175702267627853, C_minus: 0.21802529632990672
# Gradient estimate: [0.02275348]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0225729  0.16221681 4.51239217 0.38157832 0.33912089 3.75163804]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21754721822725162, C_minus: 0.2171991536930975
# Gradient estimate: [-0.01740323]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02257406 0.16221797 4.51239333 0.38157948 0.33912205 3.7516392 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21705523846370767, C_minus: 0.21797773685126876
# Gradient estimate: [0.04612492]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02257101 0.16221492 4.51239028 0.38157643 0.339119   3.75163615]]
# Iteration 120/1000, KL Divergence: 0.217601
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21576209024431509, C_minus: 0.21787703617542054
# Gradient estimate: [-0.1057473]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02257794 0.16222185 4.51239721 0.38158336 0.33912593 3.75164308]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21701009755994352, C_minus: 0.21852234064715856
# Gradient estimate: [-0.07561215]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02258286 0.16222677 4.51240213 0.38158828 0.33913085 3.751648  ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21761875052841936, C_minus: 0.2170644341772811
# Gradient estimate: [-0.02771582]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02258465 0.16222856 4.51240392 0.38159007 0.33913264 3.75164979]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21705874348314172, C_minus: 0.21812884377824684
# Gradient estimate: [-0.05350501]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02258807 0.16223198 4.51240734 0.3815935  0.33913606 3.75165321]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21739375244391473, C_minus: 0.21778355679118203
# Gradient estimate: [-0.01949022]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02258931 0.16223322 4.51240858 0.38159473 0.3391373  3.75165445]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21843468188504586, C_minus: 0.21756535973380633
# Gradient estimate: [-0.04346611]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02259205 0.16223596 4.51241132 0.38159747 0.33914004 3.75165719]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.218587542522181, C_minus: 0.21783001250629574
# Gradient estimate: [0.0378765]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02258968 0.16223359 4.51240895 0.3815951  0.33913767 3.75165482]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2170298090892308, C_minus: 0.21749620639990955
# Gradient estimate: [-0.02331987]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02259113 0.16223504 4.5124104  0.38159655 0.33913912 3.75165626]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21833169767365904, C_minus: 0.2173990892362952
# Gradient estimate: [0.04663042]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02258826 0.16223217 4.51240753 0.38159368 0.33913625 3.7516534 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21909623831761388, C_minus: 0.21752409532794834
# Gradient estimate: [-0.07860715]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02259306 0.16223697 4.51241233 0.38159848 0.33914105 3.7516582 ]]
# Iteration 130/1000, KL Divergence: 0.217596
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21681112256698365, C_minus: 0.2179272364565069
# Gradient estimate: [-0.05580569]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02259644 0.16224035 4.51241571 0.38160186 0.33914443 3.75166158]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21747717582149137, C_minus: 0.21756053395142314
# Gradient estimate: [-0.00416791]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02259669 0.1622406  4.51241596 0.38160211 0.33914468 3.75166183]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21752601844408234, C_minus: 0.21726135535841554
# Gradient estimate: [0.01323315]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0225959  0.16223981 4.51241517 0.38160132 0.33914389 3.75166104]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21757857582496407, C_minus: 0.21645224948583658
# Gradient estimate: [-0.05631632]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02259924 0.16224315 4.51241851 0.38160466 0.33914723 3.75166438]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2182289367948565, C_minus: 0.2177011962580972
# Gradient estimate: [0.02638703]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02259769 0.16224159 4.51241696 0.38160311 0.33914568 3.75166282]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21723655779621082, C_minus: 0.2173340453097134
# Gradient estimate: [0.00487438]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0225974  0.16224131 4.51241667 0.38160282 0.33914539 3.75166254]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21772057879042997, C_minus: 0.21767520856325068
# Gradient estimate: [-0.00226851]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02259753 0.16224144 4.5124168  0.38160296 0.33914552 3.75166267]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21804905198764982, C_minus: 0.21786968946610835
# Gradient estimate: [-0.00896813]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02259805 0.16224196 4.51241732 0.38160347 0.33914604 3.75166319]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2178539658108709, C_minus: 0.21742149458974847
# Gradient estimate: [0.02162356]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02259681 0.16224072 4.51241608 0.38160224 0.33914481 3.75166195]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21688744784309055, C_minus: 0.21778816953491395
# Gradient estimate: [-0.04503608]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02259937 0.16224328 4.51241864 0.38160479 0.33914736 3.75166451]]
# Iteration 140/1000, KL Divergence: 0.217944
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21740310836561436, C_minus: 0.21747106851393955
# Gradient estimate: [0.00339801]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02259918 0.16224309 4.51241845 0.3816046  0.33914717 3.75166431]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21699313919816943, C_minus: 0.21779333992047034
# Gradient estimate: [-0.04001004]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02260141 0.16224532 4.51242069 0.38160684 0.33914941 3.75166655]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21771402686939562, C_minus: 0.21778289741412182
# Gradient estimate: [-0.00344353]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02260161 0.16224551 4.51242088 0.38160703 0.3391496  3.75166674]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2179031569824878, C_minus: 0.21811026078383253
# Gradient estimate: [-0.01035519]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02260218 0.16224609 4.51242145 0.3816076  0.33915017 3.75166732]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21738370260376538, C_minus: 0.21682970176545552
# Gradient estimate: [-0.02770004]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0226037  0.1622476  4.51242297 0.38160912 0.33915169 3.75166883]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21767902225082061, C_minus: 0.2172874064101793
# Gradient estimate: [-0.01958079]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02260476 0.16224867 4.51242403 0.38161018 0.33915275 3.7516699 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21734192080644596, C_minus: 0.21770625887266018
# Gradient estimate: [-0.0182169]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02260575 0.16224965 4.51242502 0.38161117 0.33915374 3.75167088]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21735752552994053, C_minus: 0.21683057644115283
# Gradient estimate: [-0.02634745]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02260716 0.16225107 4.51242643 0.38161258 0.33915515 3.7516723 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21860099444916586, C_minus: 0.21807076297268088
# Gradient estimate: [-0.02651157]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02260857 0.16225248 4.51242785 0.381614   0.33915657 3.75167371]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2172111475073486, C_minus: 0.2186077857762761
# Gradient estimate: [-0.06983191]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02261227 0.16225618 4.51243155 0.3816177  0.33916027 3.75167741]]
# Iteration 150/1000, KL Divergence: 0.218238
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21831371683028988, C_minus: 0.21692251508262186
# Gradient estimate: [-0.06956009]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02261593 0.16225984 4.51243521 0.38162136 0.33916393 3.75168107]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21708303097603582, C_minus: 0.21810293541413403
# Gradient estimate: [-0.05099522]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0226186  0.16226251 4.51243787 0.38162402 0.33916659 3.75168374]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21759998138813058, C_minus: 0.2171725609795126
# Gradient estimate: [-0.02137102]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02261971 0.16226362 4.51243898 0.38162513 0.3391677  3.75168485]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21734720333101443, C_minus: 0.21767244516861076
# Gradient estimate: [-0.01626209]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02262055 0.16226446 4.51243982 0.38162597 0.33916854 3.75168569]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21704386406383996, C_minus: 0.2177305530314308
# Gradient estimate: [-0.03433445]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02262231 0.16226622 4.51244158 0.38162773 0.3391703  3.75168745]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21748207565356137, C_minus: 0.21783913327877805
# Gradient estimate: [-0.01785288]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02262322 0.16226713 4.51244249 0.38162864 0.33917121 3.75168836]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21777404417890972, C_minus: 0.21719239312812816
# Gradient estimate: [0.02908255]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02262175 0.16226566 4.51244102 0.38162717 0.33916974 3.75168689]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21759754985783802, C_minus: 0.2184670093631443
# Gradient estimate: [0.04347298]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02261956 0.16226347 4.51243883 0.38162498 0.33916755 3.7516847 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21783605492281777, C_minus: 0.21895705652661548
# Gradient estimate: [-0.05605008]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02262236 0.16226627 4.51244164 0.38162779 0.33917036 3.7516875 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2167902016237899, C_minus: 0.21795629530783225
# Gradient estimate: [-0.05830468]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02262526 0.16226917 4.51244453 0.38163068 0.33917325 3.7516904 ]]
# Iteration 160/1000, KL Divergence: 0.217967
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21709297589597193, C_minus: 0.21804447310747027
# Gradient estimate: [-0.04757486]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02262761 0.16227152 4.51244688 0.38163303 0.3391756  3.75169275]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21787335957872075, C_minus: 0.2181181177646433
# Gradient estimate: [0.01223791]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02262701 0.16227092 4.51244628 0.38163243 0.339175   3.75169215]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21741643885213757, C_minus: 0.21772587711107988
# Gradient estimate: [-0.01547191]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02262776 0.16227167 4.51244704 0.38163319 0.33917576 3.7516929 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21755988972554507, C_minus: 0.21741657740484435
# Gradient estimate: [0.00716562]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02262742 0.16227133 4.51244669 0.38163284 0.33917541 3.75169256]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2175947029788401, C_minus: 0.2177931652048764
# Gradient estimate: [-0.00992311]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0226279  0.1622718  4.51244717 0.38163332 0.33917589 3.75169303]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21751172728797313, C_minus: 0.21753560624061363
# Gradient estimate: [-0.00119395]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02262795 0.16227186 4.51244722 0.38163338 0.33917594 3.75169309]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21763402494094045, C_minus: 0.2171293919857317
# Gradient estimate: [-0.02523165]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02262915 0.16227306 4.51244843 0.38163458 0.33917715 3.75169429]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21679149761972336, C_minus: 0.2183223935064073
# Gradient estimate: [-0.07654479]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02263278 0.16227669 4.51245205 0.3816382  0.33918077 3.75169792]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21819179786434148, C_minus: 0.21858270407871974
# Gradient estimate: [-0.01954531]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0226337  0.16227761 4.51245297 0.38163912 0.33918169 3.75169884]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21789412191547583, C_minus: 0.21712403914293726
# Gradient estimate: [-0.03850414]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0226355  0.16227941 4.51245477 0.38164092 0.33918349 3.75170064]]
# Iteration 170/1000, KL Divergence: 0.217880
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21775594261419376, C_minus: 0.21747182261229217
# Gradient estimate: [-0.014206]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02263616 0.16228007 4.51245543 0.38164158 0.33918415 3.7517013 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21691687705160478, C_minus: 0.21675710188861394
# Gradient estimate: [0.00798876]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02263579 0.1622797  4.51245506 0.38164121 0.33918378 3.75170093]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21692803174933276, C_minus: 0.21826148339928003
# Gradient estimate: [-0.06667258]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02263886 0.16228276 4.51245813 0.38164428 0.33918685 3.75170399]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2186738845445617, C_minus: 0.21652184104357802
# Gradient estimate: [-0.10760218]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02264377 0.16228768 4.51246305 0.3816492  0.33919177 3.75170891]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21704155690628663, C_minus: 0.21799847863009011
# Gradient estimate: [-0.04784609]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02264595 0.16228986 4.51246522 0.38165137 0.33919394 3.75171109]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21721959998488355, C_minus: 0.21816155166343087
# Gradient estimate: [-0.04709758]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02264808 0.16229199 4.51246735 0.3816535  0.33919607 3.75171322]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2174708720635129, C_minus: 0.21761550584788858
# Gradient estimate: [0.00723169]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02264775 0.16229166 4.51246702 0.38165318 0.33919575 3.75171289]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21803420750370986, C_minus: 0.21701492477058404
# Gradient estimate: [-0.05096414]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02265003 0.16229394 4.5124693  0.38165545 0.33919802 3.75171517]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21725108835493373, C_minus: 0.21784448562080558
# Gradient estimate: [0.02966986]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02264871 0.16229262 4.51246798 0.38165413 0.3391967  3.75171385]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21772343518661727, C_minus: 0.21731346795818007
# Gradient estimate: [-0.02049836]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02264962 0.16229353 4.51246889 0.38165504 0.33919761 3.75171476]]
# Iteration 180/1000, KL Divergence: 0.217939
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2178594304180821, C_minus: 0.2178109407193075
# Gradient estimate: [-0.00242448]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02264972 0.16229363 4.512469   0.38165515 0.33919772 3.75171486]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2181352267252847, C_minus: 0.21833353355996524
# Gradient estimate: [-0.00991534]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02265016 0.16229407 4.51246943 0.38165558 0.33919815 3.7517153 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21707089756239326, C_minus: 0.21772686419537204
# Gradient estimate: [-0.03279833]
# Gradient estimate shape: (1,)
# ...
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21751304614210515, C_minus: 0.2181301493312225
# Gradient estimate: [-0.03085516]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02290971 0.16255362 4.51272898 0.38191513 0.3394577  3.75197485]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21829884721828188, C_minus: 0.21726957666206953
# Gradient estimate: [-0.05146353]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291015 0.16255405 4.51272942 0.38191557 0.33945814 3.75197528]]
# Iteration 940/1000, KL Divergence: 0.217683
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2176388645829287, C_minus: 0.21758407726573972
# Gradient estimate: [-0.00273937]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291017 0.16255408 4.51272944 0.38191559 0.33945816 3.75197531]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21830383413989266, C_minus: 0.2172669112010389
# Gradient estimate: [-0.05184615]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291061 0.16255452 4.51272988 0.38191603 0.3394586  3.75197575]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21788571222269618, C_minus: 0.21764966717585357
# Gradient estimate: [0.01180225]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291051 0.16255442 4.51272978 0.38191593 0.3394585  3.75197565]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21766213988115868, C_minus: 0.217158571583963
# Gradient estimate: [0.02517841]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0229103  0.1625542  4.51272957 0.38191572 0.33945829 3.75197543]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21830223145604002, C_minus: 0.21758762335681192
# Gradient estimate: [-0.0357304]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0229106  0.16255451 4.51272987 0.38191602 0.33945859 3.75197574]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21712197312426176, C_minus: 0.21756919183809734
# Gradient estimate: [-0.02236094]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291079 0.1625547  4.51273006 0.38191621 0.33945878 3.75197593]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2180786900688795, C_minus: 0.21773708293333136
# Gradient estimate: [-0.01708036]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291093 0.16255484 4.5127302  0.38191635 0.33945892 3.75197607]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21765825570313255, C_minus: 0.217582830812345
# Gradient estimate: [-0.00377124]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291096 0.16255487 4.51273023 0.38191639 0.33945896 3.7519761 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2181440759763843, C_minus: 0.21657437980024136
# Gradient estimate: [-0.07848481]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291162 0.16255553 4.5127309  0.38191705 0.33945962 3.75197676]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21793683985887455, C_minus: 0.2166651780728311
# Gradient estimate: [-0.06358309]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291216 0.16255607 4.51273143 0.38191758 0.33946015 3.7519773 ]]
# Iteration 950/1000, KL Divergence: 0.217526
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21742662488214726, C_minus: 0.21765205391990425
# Gradient estimate: [-0.01127145]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291225 0.16255616 4.51273153 0.38191768 0.33946025 3.75197739]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21839397549202813, C_minus: 0.21810233457101222
# Gradient estimate: [-0.01458205]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291238 0.16255628 4.51273165 0.3819178  0.33946037 3.75197751]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2176140085932654, C_minus: 0.2169012410060615
# Gradient estimate: [-0.03563838]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291267 0.16255658 4.51273195 0.3819181  0.33946067 3.75197781]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21757122400359707, C_minus: 0.21689878814233543
# Gradient estimate: [-0.03362179]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291296 0.16255686 4.51273223 0.38191838 0.33946095 3.75197809]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2173011916040416, C_minus: 0.21777874358633997
# Gradient estimate: [0.0238776]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291276 0.16255667 4.51273203 0.38191818 0.33946075 3.75197789]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21796745598555978, C_minus: 0.21762670892976288
# Gradient estimate: [0.01703735]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291261 0.16255652 4.51273189 0.38191804 0.33946061 3.75197775]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2168157495444688, C_minus: 0.21748539835393874
# Gradient estimate: [-0.03348244]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291289 0.1625568  4.51273217 0.38191832 0.33946089 3.75197803]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21691887714063599, C_minus: 0.21798532535819087
# Gradient estimate: [-0.05332241]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291334 0.16255725 4.51273261 0.38191876 0.33946133 3.75197848]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21740209078145656, C_minus: 0.2176763847867304
# Gradient estimate: [-0.0137147]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291345 0.16255736 4.51273272 0.38191888 0.33946145 3.75197859]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2177789767458011, C_minus: 0.21701974774676303
# Gradient estimate: [-0.03796145]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291377 0.16255768 4.51273304 0.38191919 0.33946176 3.75197891]]
# Iteration 960/1000, KL Divergence: 0.217281
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21768985948553662, C_minus: 0.21808071177472108
# Gradient estimate: [-0.01954261]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291393 0.16255784 4.5127332  0.38191935 0.33946192 3.75197907]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21814265894815268, C_minus: 0.21765317772755466
# Gradient estimate: [-0.02447406]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291413 0.16255804 4.51273341 0.38191956 0.33946213 3.75197927]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21758836541292603, C_minus: 0.21810737820948695
# Gradient estimate: [-0.02595064]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291435 0.16255826 4.51273362 0.38191977 0.33946234 3.75197949]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21708420472704348, C_minus: 0.21705912391340926
# Gradient estimate: [-0.00125404]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291436 0.16255827 4.51273363 0.38191978 0.33946235 3.7519795 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21729046530441112, C_minus: 0.2177429992158516
# Gradient estimate: [-0.0226267]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291455 0.16255846 4.51273382 0.38191997 0.33946254 3.75197969]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2179834580471111, C_minus: 0.21752196291168768
# Gradient estimate: [0.02307476]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291436 0.16255827 4.51273363 0.38191978 0.33946235 3.7519795 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2169483435274663, C_minus: 0.2184236708569474
# Gradient estimate: [-0.07376637]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291497 0.16255888 4.51273424 0.38192039 0.33946296 3.7519801 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21747867038751081, C_minus: 0.21691976047819975
# Gradient estimate: [0.0279455]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291474 0.16255864 4.51273401 0.38192016 0.33946273 3.75197987]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21777240428994088, C_minus: 0.2176161444614784
# Gradient estimate: [0.00781299]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291467 0.16255858 4.51273394 0.38192009 0.33946266 3.75197981]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21745279935921963, C_minus: 0.21672088227151937
# Gradient estimate: [-0.03659585]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291497 0.16255888 4.51273424 0.3819204  0.33946297 3.75198011]]
# Iteration 970/1000, KL Divergence: 0.217939
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21703368654833374, C_minus: 0.2173264669750929
# Gradient estimate: [-0.01463902]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291509 0.162559   4.51273437 0.38192052 0.33946309 3.75198023]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2179022514300117, C_minus: 0.21755962965584644
# Gradient estimate: [0.01713109]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291495 0.16255886 4.51273422 0.38192038 0.33946294 3.75198009]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21711776707374764, C_minus: 0.21724634124914743
# Gradient estimate: [0.00642871]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0229149  0.16255881 4.51273417 0.38192032 0.33946289 3.75198004]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2172893261909246, C_minus: 0.21769091053059383
# Gradient estimate: [-0.02007922]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291506 0.16255897 4.51273434 0.38192049 0.33946306 3.7519802 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21739377719110564, C_minus: 0.21756009812366092
# Gradient estimate: [-0.00831605]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291513 0.16255904 4.5127344  0.38192056 0.33946312 3.75198027]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21788365315474512, C_minus: 0.2168366784326182
# Gradient estimate: [-0.05234874]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291556 0.16255947 4.51273483 0.38192098 0.33946355 3.7519807 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2169835031510213, C_minus: 0.21665689422901688
# Gradient estimate: [0.01633045]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291543 0.16255934 4.5127347  0.38192085 0.33946342 3.75198057]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21785809586406504, C_minus: 0.2171681884845019
# Gradient estimate: [-0.03449537]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291571 0.16255962 4.51273498 0.38192113 0.3394637  3.75198085]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21661081786985753, C_minus: 0.21771741700643876
# Gradient estimate: [-0.05532996]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291616 0.16256007 4.51273543 0.38192158 0.33946415 3.7519813 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21787895239340893, C_minus: 0.2176223947428267
# Gradient estimate: [-0.01282788]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291627 0.16256017 4.51273554 0.38192169 0.33946426 3.7519814 ]]
# Iteration 980/1000, KL Divergence: 0.217125
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21780658119649193, C_minus: 0.21813095364593618
# Gradient estimate: [-0.01621862]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0229164  0.16256031 4.51273567 0.38192182 0.33946439 3.75198154]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21737967215299778, C_minus: 0.21773846698941718
# Gradient estimate: [0.01793974]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291625 0.16256016 4.51273552 0.38192167 0.33946424 3.75198139]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21728361719743797, C_minus: 0.2175827985594427
# Gradient estimate: [0.01495907]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291613 0.16256004 4.5127354  0.38192155 0.33946412 3.75198127]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21745919384321818, C_minus: 0.2177920056037169
# Gradient estimate: [0.01664059]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.022916   0.1625599  4.51273527 0.38192142 0.33946399 3.75198113]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21752106815676397, C_minus: 0.2169892464619733
# Gradient estimate: [-0.02659108]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291621 0.16256012 4.51273548 0.38192163 0.3394642  3.75198135]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21789000372367318, C_minus: 0.21741164646005554
# Gradient estimate: [0.02391786]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291602 0.16255993 4.51273529 0.38192144 0.33946401 3.75198116]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21780976301163185, C_minus: 0.218505989648597
# Gradient estimate: [-0.03481133]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0229163  0.16256021 4.51273557 0.38192172 0.33946429 3.75198144]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21800481471916663, C_minus: 0.21740867869838684
# Gradient estimate: [-0.0298068]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291654 0.16256045 4.51273581 0.38192196 0.33946453 3.75198168]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21815086362141892, C_minus: 0.21769581839836588
# Gradient estimate: [-0.02275226]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291672 0.16256063 4.512736   0.38192215 0.33946472 3.75198186]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21793096394236347, C_minus: 0.21780690712193143
# Gradient estimate: [-0.00620284]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291677 0.16256068 4.51273605 0.3819222  0.33946477 3.75198191]]
# Iteration 990/1000, KL Divergence: 0.218077
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21735085701693205, C_minus: 0.21840591769133086
# Gradient estimate: [-0.05275303]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.0229172  0.16256111 4.51273647 0.38192262 0.33946519 3.75198234]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2174706152020512, C_minus: 0.2177766085364917
# Gradient estimate: [0.01529967]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291708 0.16256098 4.51273635 0.3819225  0.33946507 3.75198221]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21699051479643192, C_minus: 0.21733525494825712
# Gradient estimate: [-0.01723701]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291721 0.16256112 4.51273649 0.38192264 0.33946521 3.75198235]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.216890404623282, C_minus: 0.2183887814001149
# Gradient estimate: [-0.07491884]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291782 0.16256173 4.51273709 0.38192324 0.33946581 3.75198296]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21672003699986442, C_minus: 0.21707366827921037
# Gradient estimate: [-0.01768156]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291796 0.16256187 4.51273723 0.38192338 0.33946595 3.7519831 ]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21813253762564594, C_minus: 0.21819881083522952
# Gradient estimate: [-0.00331366]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291799 0.16256189 4.51273726 0.38192341 0.33946598 3.75198312]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2177221226468023, C_minus: 0.2174028956442755
# Gradient estimate: [-0.01596135]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291811 0.16256202 4.51273739 0.38192354 0.33946611 3.75198325]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.2172426714177521, C_minus: 0.21772269419862647
# Gradient estimate: [-0.02400114]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291831 0.16256221 4.51273758 0.38192373 0.3394663  3.75198344]]
# theta_k shape: (1, 6)
# delta_k shape: (1,)
# C_plus: 0.21814782683157968, C_minus: 0.2165701471264298
# Gradient estimate: [-0.07888399]
# Gradient estimate shape: (1,)
# Updated theta_k_plus_1: [[3.02291894 0.16256285 4.51273821 0.38192436 0.33946693 3.75198408]]
# Target distribution sum: 1.0
